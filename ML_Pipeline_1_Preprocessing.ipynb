# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets_ml/data_raw.csv')
df.head()
# Out:
#                                                  Url           Brand  \
# 0  https://watchbase.com/panerai/pocket-watches/p...         Panerai
# 1  https://watchbase.com/patek-philippe/cubitus/5...  Patek Philippe
# 2  https://watchbase.com/patek-philippe/cubitus/5...  Patek Philippe
# 3  https://watchbase.com/patek-philippe/cubitus/5...  Patek Philippe
# 4  https://watchbase.com/patek-philippe/cubitus/7...  Patek Philippe
#
#            Family     Reference  \
# 0  Pocket Watches      PAM00529
# 1         Cubitus  5821/1AR-001
# 2         Cubitus     5822P-001
# 3         Cubitus   5821/1A-001
# 4         Cubitus   7128/1R-001
#
#                                                 Name  \
# 0                     Pocket Watch 3 Days Oro Bianco
# 1  Cubitus Date 45 Stainless Steel - Rose Gold / ...
# 2   Cubitus Instantaneous Grand Date Platinum / Blue
# 3            Cubitus Date 45 Stainless Steel / Green
# 4                  Cubitus Date 40 Rose Gold / Brown
#
# ...

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6298 entries, 0 to 6297
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Url               6298 non-null   object
#  1   Brand             6298 non-null   object
#  2   Family            6298 non-null   object
#  3   Reference         6298 non-null   object
#  4   Name              6298 non-null   object
#  5   Movement          6281 non-null   object
#  6   Produced          5005 non-null   object
#  7   Limited           6298 non-null   object
#  8   Case_Material     5191 non-null   object
#  9   Glass             6196 non-null   object
#  10  Case_Back         6283 non-null   object
#  11  Case_Shape        6273 non-null   object
#  12  Case_Diameter     6270 non-null   object
#  13  Lug_Width         4250 non-null   object
#  14  Water_Resistance  6076 non-null   object
#  15  Dial_Color        6263 non-null   object
# ...

# %%
df.columns = df.columns.str.replace('_', ' ')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.isna(), cbar=False, cmap='Blues', yticklabels=False)
plt.title('Missing Data Heatmap', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df = df.drop(columns=['Produced'])

# %%
df['Case Material'].value_counts()
# Out:
# Stainless Steel    3426
# White Gold          323
# Yellow Gold         321
# Titanium            267
# Rose Gold           234
# Red Gold            156
# Platinum            141
# Pink Gold           126
# Mother of Pearl      79
# Ceramic              29
# Sedna Gold           26
# Carbon                9
# Meteorite             8
# Moonshine Gold        8
# Palladium             7
# Goldtech              7
# Ceratanium            5
# Titaplast             3
# Diamond               2
# Bronze Gold           2
# Canopus Gold          2
# Silver                2
# Aluminium             2
# Bronze                1
# Armor Gold            1
# Wood                  1
# Enamel                1
# Falcon's Eye          1
# Tiger Iron            1
# Name: Case Material, dtype: int64

# %%
df['Case Material'] = df['Case Material'].apply(lambda x: 'Stainless Steel' if pd.isna(x) else x)
df['Case Material'].value_counts()
# Out:
# Stainless Steel    4533
# White Gold          323
# Yellow Gold         321
# Titanium            267
# Rose Gold           234
# Red Gold            156
# Platinum            141
# Pink Gold           126
# Mother of Pearl      79
# Ceramic              29
# Sedna Gold           26
# Carbon                9
# Meteorite             8
# Moonshine Gold        8
# Palladium             7
# Goldtech              7
# Ceratanium            5
# Titaplast             3
# Diamond               2
# Bronze Gold           2
# Canopus Gold          2
# Silver                2
# Aluminium             2
# Bronze                1
# Armor Gold            1
# Wood                  1
# Enamel                1
# Falcon's Eye          1
# Tiger Iron            1
# Name: Case Material, dtype: int64

# %%
df = df.drop(columns=['Lug Width'])

# %%
df['Water Resistance'].value_counts()
# Out:
# 100.00 m      2263
# 30.00 m       1625
# 300.00 m       571
# 50.00 m        465
# 200.00 m       423
# 120.00 m       186
# 150.00 m       160
# 60.00 m        147
# 500.00 m        66
# 600.00 m        50
# 10.00 m         22
# 1220.00 m       17
# 1000.00 m       14
# 1200.00 m       12
# 25.00 m         10
# 2000.00 m        9
# 3900.00 m        9
# 3.00 m           8
# 1500.00 m        6
# 3000.00 m        5
# 2500.00 m        3
# 11000.00 m       2
# 1.00 m           1
# 135.00 m         1
# 0.01 m           1
# Name: Water Resistance, dtype: int64

# %%
df['Water Resistance'] = df['Water Resistance'].str.replace(' m', '').astype(float)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Water Resistance'].dropna(), kde=True)
# Out:
# <Axes: xlabel='Water Resistance', ylabel='Count'>

# %%
# value_counts = df['Water Resistance'].dropna().value_counts(normalize=True)

# df.loc[df['Water Resistance'].isna(), 'Water Resistance'] = np.random.choice(
#     value_counts.index,
#     size=df['Water Resistance'].isna().sum(),
#     p=value_counts.values
# )

# %%
df['Water Resistance'] = df['Water Resistance'].fillna(df['Water Resistance'].mode()[0])

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Water Resistance'].dropna(), kde=True)
# Out:
# <Axes: xlabel='Water Resistance', ylabel='Count'>

# %%
df = df.drop(columns=['Dial Finish'])

# %%
df['Dial Indexes'].value_counts()
# Out:
# Stick / Dot                3022
# Mixed                      1016
# Arabic Numerals             928
# Roman Numerals              626
# Gem-Set Indexes             562
# None                         51
# Digital                      35
# Eastern Arabic Numerals      10
# Japanese Numerals             1
# Name: Dial Indexes, dtype: int64

# %%
df['Dial Indexes'] = df['Dial Indexes'].fillna(df['Dial Indexes'].mode()[0])

# %%
df['Dial Hands'] = df['Dial Hands'].fillna(df['Dial Hands'].mode()[0])

# %%
df['Price'] = df['Price'].astype(float)

# %%
df['Price'].describe()
# Out:
# count       5135.000000
# mean       13388.654528
# std        30827.613963
# min          450.000000
# 25%         3060.000000
# 50%         5940.000000
# 75%        11500.000000
# max      1000000.000000
# Name: Price, dtype: float64

# %%
sns.histplot(df['Price'].dropna(), kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.heatmap(df.isna(), cbar=False, cmap='Blues', yticklabels=False)
# Out:
# <Axes: >

# %%
df = df.rename(columns={'Family': 'Model'})

# %%
df['Model'].unique()
# Out:
# array(['Pocket Watches', 'Cubitus', 'Golden Ellipse', 'Gondolo',
#        'Twenty~4', 'Aquanaut', 'Nautilus', 'Complications', 'Calatrava',
#        'Grand Complications', 'Clocks & Instruments', 'Pre-Vendome',
#        'Mare Nostrum', 'Ferrari', 'Luminor Due', 'Radiomir 1940',
#        'Submersible', 'Radiomir', 'Luminor 1950', 'Luminor', 'Tortue',
#        'Crash de Cartier', 'Ronde de Cartier', 'Drive de Cartier',
#        'Clé de Cartier', 'Santos de Cartier', 'Rotonde de Cartier',
#        'Ballon Blue de Cartier', 'Calibre de Cartier', 'Tank',
#        'Professional', 'Merchandise', 'Chronomat 28', 'Chronomat 38',
#        'Vintage', 'Chrono-Matic', 'Exospace', 'Windrider', 'Airwolf',
#        'Chronoliner', 'Chronomat 32', 'Skyracer', 'Chronomat 36',
#        'Chronomat Evolution', "Superocean Heritage '57", 'Cockpit B50',
#        'Chronomat 40 GMT', 'Cockpit', 'Emergency', 'Super Chronomat',
#        'Chronospace', 'Endurance Pro', 'Chronomat B01 41', 'Aerospace',
# ...

# %%
df = df.drop(columns=['Reference', 'Name'])

# %%
df['Movement']
# Out:
# 0                   Panerai caliber P.3000/10
# 1           Patek Philippe caliber 26‑330 S C
# 2       Patek Philippe caliber 240 PS CI J LU
# 3           Patek Philippe caliber 26‑330 S C
# 4       Patek Philippe caliber 26‑330 S C/434
#                         ...
# 6293                       Rolex caliber 2236
# 6294                       Rolex caliber 2236
# 6295                    Longines caliber L963
# 6296                  Longines caliber L592.2
# 6297                    Longines caliber L963
# Name: Movement, Length: 6298, dtype: object

# %%
df['Limited'].value_counts()
# Out:
# No                 5573
# Yes, 1 unit          66
# Yes, 500 units       65
# Yes, 100 units       64
# Yes, 1000 units      42
#                    ...
# Yes, 163 units        1
# Yes, 63 units         1
# Yes, 176 units        1
# Yes, 690 units        1
# Yes, 78 units         1
# Name: Limited, Length: 146, dtype: int64

# %%
df['Limited'] = df['Limited'].str.split(',').str[0]

# %%
df['Case Material'].value_counts()
# Out:
# Stainless Steel    4533
# White Gold          323
# Yellow Gold         321
# Titanium            267
# Rose Gold           234
# Red Gold            156
# Platinum            141
# Pink Gold           126
# Mother of Pearl      79
# Ceramic              29
# Sedna Gold           26
# Carbon                9
# Meteorite             8
# Moonshine Gold        8
# Palladium             7
# Goldtech              7
# Ceratanium            5
# Titaplast             3
# Diamond               2
# Bronze Gold           2
# Canopus Gold          2
# Silver                2
# Aluminium             2
# Bronze                1
# Armor Gold            1
# Wood                  1
# Enamel                1
# Falcon's Eye          1
# Tiger Iron            1
# Name: Case Material, dtype: int64

# %%
df['Glass'].value_counts()
# Out:
# Sapphire    6034
# Plexi        119
# Mineral       43
# Name: Glass, dtype: int64

# %%
df['Glass'] = df['Glass'].fillna(df['Glass'].mode()[0])

# %%
df['Case Back'].value_counts()
# Out:
# Closed         4244
# Open           1961
# Hinged           53
# Hunter           23
# Double Dial       2
# Name: Case Back, dtype: int64

# %%
df['Case Back'] = df['Case Back'].fillna(df['Case Back'].mode()[0])

# %%
df['Case Shape'].value_counts()
# Out:
# Round          5216
# Cushion         526
# Rectangular     186
# Tonneau         107
# Oval             92
# Other            78
# Square           68
# Name: Case Shape, dtype: int64

# %%
df['Case Shape'] = df['Case Shape'].fillna(df['Case Shape'].mode()[0])

# %%
df['Case Diameter'].unique()
# Out:
# array(['50.00 mm', '45.00 mm', '40.00 mm', '59.00 mm', '52.00 mm',
#        '34.50 mm', '27.40 mm', '28.60 mm', '30.00 mm', '29.60 mm',
#        '31.00 mm', '32.00 mm', '33.40 mm', '32.40 mm', '31.10 mm',
#        '42.00 mm', nan, '36.00 mm', '24.00 mm', '25.10 mm', '25.00 mm',
#        '22.00 mm', '44.10 mm', '48.00 mm', '44.00 mm', '35.60 mm',
#        '35.20 mm', '33.60 mm', '40.50 mm', '37.50 mm', '49.25 mm',
#        '41.00 mm', '40.80 mm', '38.80 mm', '39.90 mm', '42.20 mm',
#        '38.00 mm', '38.60 mm', '39.00 mm', '35.00 mm', '37.00 mm',
#        '40.20 mm', '38.50 mm', '39.50 mm', '39.40 mm', '200.00 mm',
#        '60.00 mm', '65.00 mm', '37.60 mm', '33.00 mm', '47.40 mm',
#        '36.70 mm', '33.70 mm', '37.20 mm', '40.60 mm', '42.80 mm',
#        '47.00 mm', '49.00 mm', '34.60 mm', '28.15 mm', '41.30 mm',
#        '31.40 mm', '39.80 mm', '43.50 mm', '43.00 mm', '36.60 mm',
#        '42.10 mm', '46.00 mm', '15.00 mm', '29.80 mm', '34.30 mm',
# ...

# %%
df['Case Diameter'] = df['Case Diameter'].str.replace(' mm', '').astype(float)

# %%
df['Case Diameter'] = df['Case Diameter'].fillna(df['Case Diameter'].mode()[0])

# %%
df['Dial Color'].value_counts()
# Out:
# Black          2049
# Silver         1050
# White           895
# Blue            864
# Grey            298
# Brown           202
# Green           199
# Champagne       165
# Beige            97
# Pink             62
# Red              61
# Multi-Color      55
# Paved            51
# Ivory            35
# Purple           31
# Bronze           31
# Yellow           29
# Skeleton         28
# Orange           13
# Rose             12
# Turquoise        12
# Gold              7
# Salmon            6
# Bordeaux          5
# Diamonds          4
# Taupe             1
# See-through       1
# Name: Dial Color, dtype: int64

# %%
df['Dial Color'] = df['Dial Color'].fillna(df['Dial Color'].mode()[0])

# %%
df['Dial Indexes'].value_counts()
# Out:
# Stick / Dot                3069
# Mixed                      1016
# Arabic Numerals             928
# Roman Numerals              626
# Gem-Set Indexes             562
# None                         51
# Digital                      35
# Eastern Arabic Numerals      10
# Japanese Numerals             1
# Name: Dial Indexes, dtype: int64

# %%
df['Dial Hands'].value_counts()
# Out:
# Stick                        3534
# Sword                         497
# Feuille                       491
# Proprietary                   341
# Alpha                         339
# Arrow                         310
# Dauphine                      299
# Mercedes                      132
# Syringe                       117
# Losange                        70
# Rolex Professional (Maxi)      37
# Poire                          36
# Breguet                        34
# Lancette                       24
# Baton                          19
# Cathedrale                     17
# Spade                           1
# Name: Dial Hands, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6298 entries, 0 to 6297
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Url               6298 non-null   object
#  1   Brand             6298 non-null   object
#  2   Model             6298 non-null   object
#  3   Movement          6281 non-null   object
#  4   Limited           6298 non-null   object
#  5   Case Material     6298 non-null   object
#  6   Glass             6298 non-null   object
#  7   Case Back         6298 non-null   object
#  8   Case Shape        6298 non-null   object
#  9   Case Diameter     6298 non-null   float64
#  10  Water Resistance  6298 non-null   float64
#  11  Dial Color        6298 non-null   object
#  12  Dial Indexes      6298 non-null   object
#  13  Dial Hands        6298 non-null   object
#  14  Price             5135 non-null   float64
# dtypes: float64(3), object(12)
# memory usage: 738.2+ KB

# %%
# df = df.drop(columns=['Url'])

# %%
df.to_csv('datasets_ml/data_preprocessed.csv', index=False)
