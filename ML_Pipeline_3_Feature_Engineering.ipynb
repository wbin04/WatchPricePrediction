# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets_ml/data_preprocessed.csv')
df.head()
# Out:
#                                                  Url           Brand  \
# 0  https://watchbase.com/panerai/pocket-watches/p...         Panerai
# 1  https://watchbase.com/patek-philippe/cubitus/5...  Patek Philippe
# 2  https://watchbase.com/patek-philippe/cubitus/5...  Patek Philippe
# 3  https://watchbase.com/patek-philippe/cubitus/5...  Patek Philippe
# 4  https://watchbase.com/patek-philippe/cubitus/7...  Patek Philippe
#
#             Model                               Movement Limited  \
# 0  Pocket Watches              Panerai caliber P.3000/10     Yes
# 1         Cubitus      Patek Philippe caliber 26‑330 S C      No
# 2         Cubitus  Patek Philippe caliber 240 PS CI J LU      No
# 3         Cubitus      Patek Philippe caliber 26‑330 S C      No
# 4         Cubitus  Patek Philippe caliber 26‑330 S C/434      No
#
#      Case Material     Glass Case Back Case Shape  Case Diameter  \
# 0       White Gold  Sapphire    Hunter    Cushion           50.0
# ...

# %% [markdown]
# #### Outlier Treatment for `Case Diameter`

# %%
df['Case Diameter'].unique()
# Out:
# array([ 50.  ,  45.  ,  40.  ,  59.  ,  52.  ,  34.5 ,  27.4 ,  28.6 ,
#         30.  ,  29.6 ,  31.  ,  32.  ,  33.4 ,  32.4 ,  31.1 ,  42.  ,
#         36.  ,  24.  ,  25.1 ,  25.  ,  22.  ,  44.1 ,  48.  ,  44.  ,
#         35.6 ,  35.2 ,  33.6 ,  40.5 ,  37.5 ,  49.25,  41.  ,  40.8 ,
#         38.8 ,  39.9 ,  42.2 ,  38.  ,  38.6 ,  39.  ,  35.  ,  37.  ,
#         40.2 ,  38.5 ,  39.5 ,  39.4 , 200.  ,  60.  ,  65.  ,  37.6 ,
#         33.  ,  47.4 ,  36.7 ,  33.7 ,  37.2 ,  40.6 ,  42.8 ,  47.  ,
#         49.  ,  34.6 ,  28.15,  41.3 ,  31.4 ,  39.8 ,  43.5 ,  43.  ,
#         36.6 ,  42.1 ,  46.  ,  15.  ,  29.8 ,  34.3 ,  26.1 ,  25.5 ,
#        500.  ,  28.  , 350.  , 120.  ,  43.7 ,  31.8 ,  51.  ,  48.7 ,
#         44.8 ,  41.1 ,  33.2 ,  45.4 ,  48.4 ,  29.  ,  41.5 ,  41.8 ,
#         42.5 ,  46.2 ,  46.5 ,  43.8 ,  55.  ,  39.7 ,  34.  ,  37.1 ,
#         43.1 ,  40.4 ,  44.2 ,  40.9 ,  42.3 ,  45.5 ,  42.4 ,  35.1 ,
# ...

# %%
sns.histplot(df['Case Diameter'], bins=50, color=sns.color_palette("Set2")[0])
plt.title('Distribution of Case Diameter')
plt.xlabel('Case Diameter')
plt.ylabel('Count')
plt.show()

# %%
pd.set_option('display.max_colwidth', None)
df[df['Case Diameter'] > 60][['Url']]
# Out:
#                                                             Url
# 338   https://watchbase.com/panerai/clocks-instruments/pam00584
# 339   https://watchbase.com/panerai/clocks-instruments/pam00583
# 340   https://watchbase.com/panerai/clocks-instruments/pam00582
# 341   https://watchbase.com/panerai/clocks-instruments/pam00585
# 344   https://watchbase.com/panerai/clocks-instruments/pam00581
# 953     https://watchbase.com/breitling/merchandise/jz600300-15
# 955     https://watchbase.com/breitling/merchandise/jz600000-10
# 956     https://watchbase.com/breitling/merchandise/jz600250-14
# 5099   https://watchbase.com/omega/museum-collection/5109-20-00
# 5120   https://watchbase.com/omega/museum-collection/5110-20-00

# %%
df = df[df['Case Diameter'] <= 60]

# %%
sns.histplot(df['Case Diameter'], bins=50, color=sns.color_palette("Set2")[0])
plt.title('Distribution of Case Diameter')
plt.xlabel('Case Diameter')
plt.ylabel('Count')
plt.show()

# %%
df['Case Diameter'].describe()
# Out:
# count    6288.000000
# mean       39.079405
# std         5.819267
# min        15.000000
# 25%        36.600000
# 50%        41.000000
# 75%        42.100000
# max        60.000000
# Name: Case Diameter, dtype: float64

# %%
df['Case Diameter'].unique()
# Out:
# array([50.  , 45.  , 40.  , 59.  , 52.  , 34.5 , 27.4 , 28.6 , 30.  ,
#        29.6 , 31.  , 32.  , 33.4 , 32.4 , 31.1 , 42.  , 36.  , 24.  ,
#        25.1 , 25.  , 22.  , 44.1 , 48.  , 44.  , 35.6 , 35.2 , 33.6 ,
#        40.5 , 37.5 , 49.25, 41.  , 40.8 , 38.8 , 39.9 , 42.2 , 38.  ,
#        38.6 , 39.  , 35.  , 37.  , 40.2 , 38.5 , 39.5 , 39.4 , 60.  ,
#        37.6 , 33.  , 47.4 , 36.7 , 33.7 , 37.2 , 40.6 , 42.8 , 47.  ,
#        49.  , 34.6 , 28.15, 41.3 , 31.4 , 39.8 , 43.5 , 43.  , 36.6 ,
#        42.1 , 46.  , 15.  , 29.8 , 34.3 , 26.1 , 25.5 , 28.  , 43.7 ,
#        31.8 , 51.  , 48.7 , 44.8 , 41.1 , 33.2 , 45.4 , 48.4 , 29.  ,
#        41.5 , 41.8 , 42.5 , 46.2 , 46.5 , 43.8 , 55.  , 39.7 , 34.  ,
#        37.1 , 43.1 , 40.4 , 44.2 , 40.9 , 42.3 , 45.5 , 42.4 , 35.1 ,
#        41.6 , 16.  , 18.  , 21.  , 22.5 , 20.4 , 19.5 , 21.3 , 20.  ,
#        21.8 , 23.  , 23.5 , 26.  , 26.5 , 29.5 , 18.9 , 21.9 , 24.9 ,
# ...

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['Case Diameter'], color=sns.color_palette("Set2")[1])  
plt.title('Distribution of Case Diameter')
plt.xlabel('Case Diameter')
plt.show()

# %% [markdown]
# #### Categorization of `Water Resistance`

# %%
df['Water Resistance'].describe()
# Out:
# count     6288.000000
# mean       135.163806
# std        301.331829
# min          0.010000
# 25%         30.000000
# 50%        100.000000
# 75%        100.000000
# max      11000.000000
# Name: Water Resistance, dtype: float64

# %%
sns.histplot(df['Water Resistance'], bins=100, color=sns.color_palette("Set2")[2])
plt.title('Distribution of Water Resistance')
plt.xlabel('Water Resistance')
plt.ylabel('Count')
plt.show()

# %%
df['Water Resistance'].value_counts()
# Out:
# 100.00      2475
# 30.00       1625
# 300.00       571
# 50.00        465
# 200.00       423
# 120.00       186
# 150.00       160
# 60.00        147
# 500.00        66
# 600.00        50
# 10.00         22
# 1220.00       17
# 1000.00       14
# 1200.00       12
# 25.00         10
# 2000.00        9
# 3900.00        9
# 3.00           8
# 1500.00        6
# 3000.00        5
# 2500.00        3
# 11000.00       2
# 1.00           1
# 135.00         1
# 0.01           1
# Name: Water Resistance, dtype: int64

# %%
bins = [0, 30, 100, 200, 500, float('inf')]
labels = ['Low', 'Basic', 'Standard', 'Professional', 'Extreme']
df['WaterResistanceLevel'] = pd.cut(df['Water Resistance'], bins=bins, labels=labels, right=False)

# %%
print(df['WaterResistanceLevel'].value_counts())
# Out:
# Standard        2822
# Basic           2237
# Professional     994
# Extreme          193
# Low               42
# Name: WaterResistanceLevel, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x=df['WaterResistanceLevel'], order=labels, palette='Set2')
plt.title('Water Resistance Level Distribution')
plt.xlabel('Water Resistance Level')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8868\2332892968.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['WaterResistanceLevel'], order=labels, palette='Set2')

# %% [markdown]
# #### Data Cleaning for `Brand` and `Model`

# %%
df['Brand'] = df['Brand'].str.replace('-', ' ').str.lower()
df['Brand'] = df['Brand'].str.replace('bell ross', 'bell & ross')

# %%
df['Model'] = df['Model'].str.replace(' watches', '')

# %%
import re

def remove_brand_from_model(model_name):
    brands = df['Brand'].unique().tolist()
    for brand in brands:
        model_name = re.sub(rf"^{re.escape(brand)}\s*", "", model_name)
    return model_name

df['Model'] = df['Model'].apply(lambda x: remove_brand_from_model(x.lower().strip()))

print(df['Model'].unique())
# Out:
# ['pocket watches' 'cubitus' 'golden ellipse' 'gondolo' 'twenty~4'
#  'aquanaut' 'nautilus' 'complications' 'calatrava' 'grand complications'
#  'clocks & instruments' 'pre-vendome' 'mare nostrum' 'ferrari'
#  'luminor due' 'radiomir 1940' 'submersible' 'radiomir' 'luminor 1950'
#  'luminor' 'tortue' 'crash de cartier' 'ronde de cartier'
#  'drive de cartier' 'clé de cartier' 'santos de cartier'
#  'rotonde de cartier' 'ballon blue de cartier' 'calibre de cartier' 'tank'
#  'professional' 'chronomat 28' 'chronomat 38' 'vintage' 'chrono-matic'
#  'exospace' 'windrider' 'airwolf' 'chronoliner' 'chronomat 32' 'skyracer'
#  'chronomat 36' 'chronomat evolution' "superocean heritage '57"
#  'cockpit b50' 'chronomat 40 gmt' 'cockpit' 'emergency' 'super chronomat'
#  'chronospace' 'endurance pro' 'chronomat b01 41' 'aerospace'
#  'for bentley' 'top time' 'montbrillant' 'avi' 'premier'
#  'chronomat b01 42' 'superocean' 'transocean' 'superocean heritage' 'colt'
# ...

# %%
df['Model'].groupby(df['Brand']).count()
# Out:
# Brand
# breitling         1249
# cartier            217
# iwc                412
# longines          1109
# omega              843
# panerai            347
# patek philippe     383
# rolex              796
# tag heuer          429
# tudor              503
# Name: Model, dtype: int64

# %% [markdown]
# #### `Price` Distribution Analysis of Top `Model` by `Brand`

# %% [markdown]
# - Chuyển `Price` thành `LogPrice` để giảm độ lệch phải của chiều dữ liệu

# %%
top_models = df['Model'].value_counts().head(10).index
df_top_models = df[df['Model'].isin(top_models)].copy()
df_top_models['LogPrice'] = np.log1p(df_top_models['Price'])

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_top_models, x='Model', y='LogPrice', hue='Brand', widths=0.5, dodge=False, palette='Set2')
plt.xticks(rotation=45, ha='right')
plt.title('Price Distribution Analysis of Top Model by Brand')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `LogPrice` Distribution by `Limited` and `Brand`

# %%
plt.figure(figsize=(14, 8))
sns.violinplot(data=df_top_models, x='Limited', y='LogPrice', hue='Brand', width=0.9, split=True, inner="quartile", palette='Set2')
plt.title('LogPrice Distribution by Limited and Brand')
# Out:
# Text(0.5, 1.0, 'LogPrice Distribution by Limited and Brand')

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df_top_models, x='Limited', y='LogPrice', hue='Brand', width=0.9, dodge=True, palette='Set2')
plt.title('LogPrice Distribution by Limited and Brand')
# Out:
# Text(0.5, 1.0, 'LogPrice Distribution by Limited and Brand')

# %% [markdown]
# #### Categorization of `Case Material`

# %%
df['Case Material'].value_counts()
# Out:
# Stainless Steel    4525
# White Gold          322
# Yellow Gold         320
# Titanium            267
# Rose Gold           234
# Red Gold            156
# Platinum            141
# Pink Gold           126
# Mother of Pearl      79
# Ceramic              29
# Sedna Gold           26
# Carbon                9
# Meteorite             8
# Moonshine Gold        8
# Palladium             7
# Goldtech              7
# Ceratanium            5
# Titaplast             3
# Diamond               2
# Bronze Gold           2
# Canopus Gold          2
# Silver                2
# Aluminium             2
# Bronze                1
# Armor Gold            1
# Wood                  1
# Enamel                1
# Falcon's Eye          1
# Tiger Iron            1
# Name: Case Material, dtype: int64

# %%
def group_case_material(material):
    if material in ['Stainless Steel']:
        return 'Steel'
    elif material in ['Titanium']:
        return 'Titanium'
    elif material in ['White Gold', 'Pink Gold', 'Rose Gold', 'Red Gold', 'Yellow Gold', 'Goldtech', 'Sedna Gold', 'Bronze Gold']:
        return 'Gold Variants'
    elif material == 'Platinum':
        return 'Platinum'
    elif material == 'Bronze':
        return 'Bronze'
    elif material in ['Ceramic', 'Carbon', 'Sapphire', 'Resin', 'Mother of Pearl']:
        return 'Synthetic'
    elif material == 'Diamond':
        return 'Diamond'
    else:
        return 'Other'

df['CaseMaterialGrouped'] = df['Case Material'].apply(group_case_material)
df['CaseMaterialGrouped'].value_counts()
# Out:
# Steel            4525
# Gold Variants    1193
# Titanium          267
# Platinum          141
# Synthetic         117
# Other              42
# Diamond             2
# Bronze              1
# Name: CaseMaterialGrouped, dtype: int64

# %%
df['LogPrice'] = np.log1p(df['Price'])

# %% [markdown]
# #### `LogPrice` Distribution by Grouped `Case Material` and `Brand`

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='CaseMaterialGrouped', y='LogPrice', hue='Brand', width=0.9, dodge=True, palette='Set2')
plt.title('LogPrice Distribution by Case Material and Brand')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `LogPrice` Distribution by `Case Material` and `Brand`

# %%
sns.catplot(
    data=df, kind='point',
    x='Brand', y='LogPrice', hue='CaseMaterialGrouped',
    height=6, aspect=2, ci='sd', palette='Set2'
)
plt.title('LogPrice Distribution by Brand and Case Material')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8868\3927975033.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.catplot(

# %%
plt.figure(figsize=(14, 8))
sns.swarmplot(data=df, x='CaseMaterialGrouped', y='LogPrice', hue='Brand', dodge=True, palette='Set2')
plt.title('LogPrice Distribution by Case Material and Brand')
plt.tight_layout()
plt.show()
# Out:
# e:\python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# e:\python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# e:\python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 63.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# e:\python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df['Glass'].value_counts()
# Out:
# Sapphire    6130
# Plexi        119
# Mineral       39
# Name: Glass, dtype: int64

# %% [markdown]
# #### `LogPrice` Distribution by `Glass` and `Brand`

# %%
plt.figure(figsize=(18, 6))
sns.pointplot(data=df, x='Glass', y='LogPrice', hue='Brand', dodge=True, palette='Set2')
plt.title('LogPrice Distribution by Glass and Brand')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `LogPrice` Distribution by `Glass` and `Case Material`

# %%
plt.figure(figsize=(18, 6))
sns.pointplot(data=df, x='Glass', y='LogPrice', hue='Case Material', dodge=True, palette='Set2')
plt.title('LogPrice Distribution by Glass and Case Material')
plt.legend(title='Case Material', loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %%
df['Case Back'].value_counts()
# Out:
# Closed         4252
# Open           1960
# Hinged           51
# Hunter           23
# Double Dial       2
# Name: Case Back, dtype: int64

# %% [markdown]
# #### `LogPrice` Distribution by `Glass` and `Case Back`

# %%
plt.figure(figsize=(18, 6))
sns.pointplot(data=df, x='Glass', y='LogPrice', hue='Case Back', dodge=True, palette='Set2')
plt.title('LogPrice Distribution by Glass and Case Back')
plt.tight_layout()
plt.show()

# %%
df['Case Shape'].value_counts()
# Out:
# Round          5239
# Cushion         521
# Rectangular     186
# Tonneau         107
# Oval             92
# Other            78
# Square           65
# Name: Case Shape, dtype: int64

# %% [markdown]
# #### `LogPrice` Distribution by `Glass` and `Case Shape`

# %%
plt.figure(figsize=(14, 8))
sns.violinplot(data=df_top_models, x='Glass', y='LogPrice', hue='Case Shape', split=True, inner="quartile", palette='Set2')
plt.title('LogPrice Distribution by Glass and Case Shape')
# Out:
# Text(0.5, 1.0, 'LogPrice Distribution by Glass and Case Shape')

# %% [markdown]
# #### Categorization of `Dial Color`

# %%
df['Dial Color'].value_counts()
# Out:
# Black          2076
# Silver         1050
# White           893
# Blue            864
# Grey            298
# Brown           202
# Green           199
# Champagne       165
# Beige            97
# Pink             62
# Red              61
# Multi-Color      55
# Paved            51
# Ivory            35
# Purple           31
# Bronze           31
# Yellow           29
# Skeleton         28
# Orange           13
# Rose             12
# Turquoise        12
# Gold              7
# Salmon            6
# Bordeaux          5
# Diamonds          4
# Taupe             1
# See-through       1
# Name: Dial Color, dtype: int64

# %%
def group_dial_color(color):
    color = color.lower()
    if color in ['black']:
        return 'Black'
    elif color in ['silver', 'white', 'champagne', 'ivory', 'mirror']:
        return 'Silver/White'
    elif color in ['blue', 'navy']:
        return 'Blue'
    elif color in ['skeleton', 'see-through']:
        return 'Skeleton'
    elif color in ['grey', 'brown', 'taupe', 'beige']:
        return 'Grey/Brown'
    elif color in ['paved', 'diamonds']:
        return 'Paved/Diamonds'
    elif color in ['multi-color', 'green', 'red', 'purple', 'orange', 'yellow', 'pink', 'salmon', 'rose']:
        return 'Colorful'
    else:
        return 'Other'

df['DialColorGrouped'] = df['Dial Color'].apply(group_dial_color)
df['DialColorGrouped'].value_counts()
# Out:
# Silver/White      2143
# Black             2076
# Blue               864
# Grey/Brown         598
# Colorful           468
# Paved/Diamonds      55
# Other               55
# Skeleton            29
# Name: DialColorGrouped, dtype: int64

# %% [markdown]
# #### `LogPrice` Distribution by `DialColorGrouped` and `Case Material`

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='DialColorGrouped', y='LogPrice', hue='CaseMaterialGrouped', dodge=True, palette='Set2')
plt.title('LogPrice Distribution by DialColorGrouped and Case Material')
plt.tight_layout()
plt.show()

# %%
df['Dial Indexes'].value_counts()
# Out:
# Stick / Dot                3069
# Mixed                      1011
# Arabic Numerals             923
# Roman Numerals              626
# Gem-Set Indexes             562
# None                         51
# Digital                      35
# Eastern Arabic Numerals      10
# Japanese Numerals             1
# Name: Dial Indexes, dtype: int64

# %% [markdown]
# #### `LogPrice` Distribution by `DialColorGrouped` and `Dial Indexes`

# %%
plt.figure(figsize=(18, 6))
sns.boxplot(x='DialColorGrouped', y='LogPrice', data=df, hue='Dial Indexes', dodge=True, palette='Set2')
plt.title('LogPrice Distribution by DialColorGrouped and Dial Indexes')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Categorization of `Dial Hands`

# %%
df['Dial Hands'].value_counts()
# Out:
# Stick                        3529
# Sword                         494
# Feuille                       491
# Proprietary                   341
# Alpha                         339
# Arrow                         310
# Dauphine                      299
# Mercedes                      132
# Syringe                       117
# Losange                        70
# Rolex Professional (Maxi)      37
# Poire                          34
# Breguet                        34
# Lancette                       24
# Baton                          19
# Cathedrale                     17
# Spade                           1
# Name: Dial Hands, dtype: int64

# %%
def group_dial_hands(hand):
    hand = hand.lower()
    if hand in ['stick', 'baton', 'alpha']:
        return 'Stick/Minimalist'
    elif hand in ['dauphine', 'lancette', 'trapezium']:
        return 'Dauphine-style'
    elif hand in ['sword', 'arrow']:
        return 'Sword-style'
    elif hand in ['feuille', 'poire']:
        return 'Leaf-style'
    elif hand in ['cathedrale', 'mercedes', 'breguet', 'syringe', 'losange']:
        return 'Traditional/Special'
    elif hand in ['proprietary']:
        return 'Proprietary'
    else:
        return 'Other'

df['DialHandsGrouped'] = df['Dial Hands'].apply(group_dial_hands)
df['DialHandsGrouped'].value_counts()
# Out:
# Stick/Minimalist       3887
# Sword-style             804
# Leaf-style              525
# Traditional/Special     370
# Proprietary             341
# Dauphine-style          323
# Other                    38
# Name: DialHandsGrouped, dtype: int64

# %% [markdown]
# #### `DialHandsGrouped` vs `Dial Indexes` heatmap

# %%
cross_tab = pd.crosstab(df['DialHandsGrouped'], df['Dial Indexes'])

plt.figure(figsize=(12, 6))
sns.heatmap(cross_tab, cmap='Blues', annot=True, fmt='d')
plt.title('DialHandsGrouped vs Dial Indexes')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `DialHandsGrouped` distribution by `Dial Indexes`

# %%
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='DialHandsGrouped', hue='Dial Indexes', dodge=True, palette='Set2')
plt.xticks(rotation=45)
plt.title('DialHandsGrouped distribution by Dial Indexes')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### `DialHandsGrouped` distribution by `DialColorGrouped`

# %%
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='DialHandsGrouped', hue='DialColorGrouped', dodge=True, palette='Set2')
plt.title('DialHandsGrouped distribution by DialColorGrouped')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Url', 'Brand', 'Model', 'Movement', 'Limited', 'Case Material',
#        'Glass', 'Case Back', 'Case Shape', 'Case Diameter', 'Water Resistance',
#        'Dial Color', 'Dial Indexes', 'Dial Hands', 'Price',
#        'WaterResistanceLevel', 'CaseMaterialGrouped', 'LogPrice',
#        'DialColorGrouped', 'DialHandsGrouped'],
#       dtype='object')

# %% [markdown]
# #### `Brand` vs `Case Material` heatmap

# %%
brand_case_material = pd.crosstab(df['Brand'], df['CaseMaterialGrouped'])

plt.figure(figsize=(12, 7))
sns.heatmap(brand_case_material, cmap='YlGnBu', annot=True, fmt='d')
plt.title('Brand vs Case Material')
plt.tight_layout()
plt.show()

# %%
numeric_df = df[['Case Diameter', 'LogPrice']]
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
df['Case Diameter'].unique()
# Out:
# array([50.  , 45.  , 40.  , 59.  , 52.  , 34.5 , 27.4 , 28.6 , 30.  ,
#        29.6 , 31.  , 32.  , 33.4 , 32.4 , 31.1 , 42.  , 36.  , 24.  ,
#        25.1 , 25.  , 22.  , 44.1 , 48.  , 44.  , 35.6 , 35.2 , 33.6 ,
#        40.5 , 37.5 , 49.25, 41.  , 40.8 , 38.8 , 39.9 , 42.2 , 38.  ,
#        38.6 , 39.  , 35.  , 37.  , 40.2 , 38.5 , 39.5 , 39.4 , 60.  ,
#        37.6 , 33.  , 47.4 , 36.7 , 33.7 , 37.2 , 40.6 , 42.8 , 47.  ,
#        49.  , 34.6 , 28.15, 41.3 , 31.4 , 39.8 , 43.5 , 43.  , 36.6 ,
#        42.1 , 46.  , 15.  , 29.8 , 34.3 , 26.1 , 25.5 , 28.  , 43.7 ,
#        31.8 , 51.  , 48.7 , 44.8 , 41.1 , 33.2 , 45.4 , 48.4 , 29.  ,
#        41.5 , 41.8 , 42.5 , 46.2 , 46.5 , 43.8 , 55.  , 39.7 , 34.  ,
#        37.1 , 43.1 , 40.4 , 44.2 , 40.9 , 42.3 , 45.5 , 42.4 , 35.1 ,
#        41.6 , 16.  , 18.  , 21.  , 22.5 , 20.4 , 19.5 , 21.3 , 20.  ,
#        21.8 , 23.  , 23.5 , 26.  , 26.5 , 29.5 , 18.9 , 21.9 , 24.9 ,
# ...

# %% [markdown]
# #### `Case Diameter` Distribution

# %%
sns.histplot(df['Case Diameter'], bins=50)
plt.title('Case Diameter Distribution')
# Out:
# Text(0.5, 1.0, 'Case Diameter Distribution')

# %% [markdown]
# #### Categorization of `Case Diameter`

# %%
bins = [0, 30, 34, 39, 43, 47, float('inf')]
labels = ['XS', 'S', 'M', 'L', 'XL', 'XXL']

df['CaseDiameterGrouped'] = pd.cut(df['Case Diameter'], bins=bins, labels=labels)
df['CaseDiameterGrouped'].value_counts().sort_index()
# Out:
# XS      641
# S       403
# M      1389
# L      2688
# XL     1030
# XXL     137
# Name: CaseDiameterGrouped, dtype: int64

# %% [markdown]
# #### `Brand` vs `CaseDiameterGrouped` heatmap

# %%
brand_case_material = pd.crosstab(df['Brand'], df['CaseDiameterGrouped'])

plt.figure(figsize=(12, 7))
sns.heatmap(brand_case_material, cmap='Set3', annot=True, fmt='d')
plt.title('Brand vs CaseDiameterGrouped')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Url', 'Brand', 'Model', 'Movement', 'Limited', 'Case Material',
#        'Glass', 'Case Back', 'Case Shape', 'Case Diameter', 'Water Resistance',
#        'Dial Color', 'Dial Indexes', 'Dial Hands', 'Price',
#        'WaterResistanceLevel', 'CaseMaterialGrouped', 'LogPrice',
#        'DialColorGrouped', 'DialHandsGrouped', 'CaseDiameterGrouped'],
#       dtype='object')

# %%
data = ['Url', 'Brand', 'Model', 'Limited', 
        'CaseMaterialGrouped', 'Glass', 'Case Shape', 'CaseDiameterGrouped', 'WaterResistanceLevel', 
        'DialColorGrouped', 'DialHandsGrouped', 'Dial Indexes', 'LogPrice']

# %%
df_data = pd.DataFrame(df[data])
df_data.head()
# Out:
#                                                          Url           Brand  \
# 0      https://watchbase.com/panerai/pocket-watches/pam00529         panerai
# 1  https://watchbase.com/patek-philippe/cubitus/5821-1ar-001  patek philippe
# 2     https://watchbase.com/patek-philippe/cubitus/5822p-001  patek philippe
# 3   https://watchbase.com/patek-philippe/cubitus/5821-1a-001  patek philippe
# 4   https://watchbase.com/patek-philippe/cubitus/7128-1r-001  patek philippe
#
#             Model Limited CaseMaterialGrouped     Glass Case Shape  \
# 0  pocket watches     Yes       Gold Variants  Sapphire    Cushion
# 1         cubitus      No               Steel  Sapphire     Square
# 2         cubitus      No            Platinum  Sapphire     Square
# 3         cubitus      No               Steel  Sapphire     Square
# 4         cubitus      No       Gold Variants  Sapphire     Square
#
#   CaseDiameterGrouped WaterResistanceLevel DialColorGrouped  DialHandsGrouped  \
# ...

# %%
df_data.to_csv('datasets/watchbase_data_featured_scrapy.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df_data.to_csv('datasets/watchbase_data_featured_scrapy.csv', index=False)
#
# File e:\python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File e:\python310\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
# ...
